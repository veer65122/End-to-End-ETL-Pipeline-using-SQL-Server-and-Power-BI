# %%
import pandas as pd
df=pd.read_csv(r'C:/Users/Lenovo/Downloads/netflix_titles.csv')

# %%
import sqlalchemy as sal

engine = sal.create_engine(
    "mssql+pyodbc://@.\\SQLEXPRESS/master?"
    "driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

conn = engine.connect()

# %%
from sqlalchemy.types import NVARCHAR
df.to_sql('netflix_raw', con=conn , index=False, if_exists = 'replace',dtype={
        'title': NVARCHAR(300),
        'director': NVARCHAR(500),
        'cast': NVARCHAR(None),
        'description': NVARCHAR(None)
    })
conn.close()

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df[df.show_id=='s5975']
# Out:
#      show_id     type                title director  \
# 5974   s5975  TV Show  แผนร้ายนายเจ้าเล่ห์      NaN
#
#                                                    cast country  \
# 5974  Chutavuth Pattarakampol, Sheranut Yusananda, N...     NaN
#
#           date_added  release_year rating  duration  \
# 5974  March 30, 2019          2016  TV-14  1 Season
#
#                                               listed_in  \
# 5974  International TV Shows, Romantic TV Shows, TV ...
#
#                                             description
# 5974  When two brothers fall for two sisters, they q...

# %%
max(df.description.dropna().str.len())
# Out:
# 248
